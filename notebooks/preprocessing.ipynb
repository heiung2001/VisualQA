# %%
import os
import json
import re
import numpy as np

from PIL import Image
from collections import defaultdict

# %% [markdown]
# ## Resize Images

# %%
def resize_image(image, size):
    return image.resize(size, Image.Resampling.LANCZOS)

def resize_images(input_dir, output_dir, size):
    for idir in os.scandir(input_dir):
        if not idir.is_dir():
            continue

        if not os.path.exists(output_dir + '/' + idir.name):
            os.makedirs(output_dir + '/' + idir.name)
        
        images = os.listdir(idir.path)
        n_images = len(images)
        for iimage, image in enumerate(images):
            try:
                with open(os.path.join(idir.path, image), 'r+b') as f:
                    with Image.open(f) as img:
                        img = resize_image(img, size)
                        img.save(os.path.join(output_dir + '/' + idir.name, image), img.format)
            except(IOError, SyntaxError) as e:
                pass

            if (iimage + 1) % 1000 == 0:
                print("[{}/{}] Resized the images and saved into '{}'."
                      .format(iimage+1, n_images, output_dir+'/'+idir.name))

# %%
input_dir = r"C:\Users\hieunc15\Documents\VisualQA\data\raw\images"
output_dir = r"C:\Users\hieunc15\Documents\VisualQA\data\processed\images"
image_size = [224, 224]

resize_images(input_dir, output_dir, image_size)
# Out:
# [1000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [2000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [3000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [4000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [5000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [6000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [7000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [8000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [9000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [10000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [11000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [12000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [13000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [14000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [15000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [16000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [17000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [18000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [19000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [20000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [21000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [22000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [23000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [24000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [25000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [26000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [27000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [28000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [29000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [30000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [31000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [32000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [33000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [34000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [35000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [36000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [37000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [38000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [39000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [40000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [41000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [42000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [43000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [44000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [45000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [46000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [47000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [48000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [49000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [50000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [51000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [52000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [53000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [54000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [55000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [56000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [57000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [58000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [59000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [60000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [61000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [62000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [63000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [64000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [65000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [66000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [67000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [68000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [69000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [70000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [71000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [72000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [73000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [74000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [75000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [76000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [77000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [78000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [79000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [80000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [81000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [82000/82783] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/train2014'.
# [1000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [2000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [3000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [4000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [5000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [6000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [7000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [8000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [9000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [10000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [11000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [12000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [13000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [14000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [15000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [16000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [17000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [18000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [19000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [20000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [21000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [22000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [23000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [24000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [25000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [26000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [27000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [28000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [29000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [30000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [31000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [32000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [33000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [34000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [35000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [36000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [37000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [38000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [39000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.
# [40000/40504] Resized the images and saved into 'C:\Users\hieunc15\Documents\VisualQA\data\processed\images/val2014'.

# %% [markdown]
# ## Make Vocab for QA

# %%
def make_vocab_questions(input_dir):
    """Make dictionary for questions and save them into text file."""
    vocab_set = set()
    SENTENCE_SPLIT_REGEX = re.compile(r'(\W+)')
    question_length = []
    datasets = os.listdir(input_dir)
    for dataset in datasets:
        with open(input_dir+'/'+dataset) as f:
            questions = json.load(f)['questions']
        set_question_length = [None]*len(questions)
        for iquestion, question in enumerate(questions):
            words = SENTENCE_SPLIT_REGEX.split(question['question'].lower())
            words = [w.strip() for w in words if len(w.strip()) > 0]
            vocab_set.update(words)
            set_question_length[iquestion] = len(words)
        question_length += set_question_length

    vocab_list = list(vocab_set)
    vocab_list.sort()
    vocab_list.insert(0, '<pad>')
    vocab_list.insert(1, '<unk>')
    
    with open(r'C:\Users\hieunc15\Documents\VisualQA\data\processed\vocab_questions.txt', 'w') as f:
        f.writelines([w+'\n' for w in vocab_list])
    
    print('Make vocabulary for questions')
    print('The number of total words of questions: %d' % len(vocab_set))
    print('Maximum length of question: %d' % np.max(question_length))


def make_vocab_answers(input_dir, n_answers):
    """Make dictionary for top n answers and save them into text file."""
    answers = defaultdict(lambda: 0)
    datasets = os.listdir(input_dir)
    for dataset in datasets:
        with open(input_dir+'/'+dataset) as f:
            annotations = json.load(f)['annotations']
        for annotation in annotations:
            for answer in annotation['answers']:
                word = answer['answer']
                if re.search(r"[^\w\s]", word):
                    continue
                answers[word] += 1
                
    answers = sorted(answers, key=answers.get, reverse=True)
    assert('<unk>' not in answers)
    top_answers = ['<unk>'] + answers[:n_answers-1] # '-1' is due to '<unk>'
    
    with open(r'C:\Users\hieunc15\Documents\VisualQA\data\processed\vocab_answers.txt', 'w') as f:
        f.writelines([w+'\n' for w in top_answers])

    print('Make vocabulary for answers')
    print('The number of total words of answers: %d' % len(answers))
    print('Keep top %d answers into vocab' % n_answers)

# %%
question_path = r"C:\Users\hieunc15\Documents\VisualQA\data\raw\questions"
annotate_path = r"C:\Users\hieunc15\Documents\VisualQA\data\raw\annotations"

n_answers = 1000    # number of answers to be kept in vocab
make_vocab_questions(question_path)
make_vocab_answers(annotate_path, n_answers)
# Out:
# Make vocabulary for questions
# The number of total words of questions: 15334
# Maximum length of question: 26
# Make vocabulary for answers
# The number of total words of answers: 181102
# Keep top 1000 answers into vocab

# %% [markdown]
# ## Build VQA input

# %%
SENTENCE_SPLIT_REGEX = re.compile(r'(\W+)')


def tokenize(sentence):
    tokens = SENTENCE_SPLIT_REGEX.split(sentence.lower())
    tokens = [t.strip() for t in tokens if len(t.strip()) > 0]
    return tokens


def load_str_list(fname):
    with open(fname) as f:
        lines = f.readlines()
    lines = [l.strip() for l in lines]
    return lines


class VocabDict:
    
    def __init__(self, vocab_file):
        self.word_list = load_str_list(vocab_file)
        self.word2idx_dict = {w:n_w for n_w, w in enumerate(self.word_list)}
        self.vocab_size = len(self.word_list)
        self.unk2idx = self.word2idx_dict['<unk>'] if '<unk>' in self.word2idx_dict else None

    def idx2word(self, n_w):
        return self.word_list[n_w]

    def word2idx(self, w):
        if w in self.word2idx_dict:
            return self.word2idx_dict[w]
        elif self.unk2idx is not None:
            return self.unk2idx
        else:
            raise ValueError('word %s not in dictionary (while dictionary does not contain <unk>)' % w)

    def tokenize_and_index(self, sentence):
        inds = [self.word2idx(w) for w in tokenize(sentence)]
        return inds

# %%
def extract_answers(q_answers, valid_answer_set):
    all_answers = [answer["answer"] for answer in q_answers]
    valid_answers = [a for a in all_answers if a in valid_answer_set]
    return all_answers, valid_answers


def vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, image_set):
    print('building vqa %s dataset' % image_set)
    if image_set in ['train2014', 'val2014']:
        load_answer = True
        with open(annotation_file % image_set) as f:
            annotations = json.load(f)['annotations']
            qid2ann_dict = {ann['question_id']: ann for ann in annotations}
    else:
        load_answer = False
    with open(question_file % image_set) as f:
        questions = json.load(f)['questions']
    coco_set_name = image_set.replace('-dev', '')
    abs_image_dir = os.path.abspath(image_dir % coco_set_name)
    image_name_template = 'COCO_'+coco_set_name+'_%012d'
    dataset = [None]*len(questions)
    
    unk_ans_count = 0
    for n_q, q in enumerate(questions):
        if (n_q+1) % 10000 == 0:
            print('processing %d / %d' % (n_q+1, len(questions)))
        image_id = q['image_id']
        question_id = q['question_id']
        image_name = image_name_template % image_id
        image_path = os.path.join(abs_image_dir, image_name+'.jpg')
        question_str = q['question']
        question_tokens = tokenize(question_str)
        
        iminfo = dict(image_name=image_name,
                      image_path=image_path,
                      question_id=question_id,
                      question_str=question_str,
                      question_tokens=question_tokens)
        
        if load_answer:
            ann = qid2ann_dict[question_id]
            all_answers, valid_answers = extract_answers(ann['answers'], valid_answer_set)
            if len(valid_answers) == 0:
                valid_answers = ['<unk>']
                unk_ans_count += 1
            iminfo['all_answers'] = all_answers
            iminfo['valid_answers'] = valid_answers
            
        dataset[n_q] = iminfo
    print('total %d out of %d answers are <unk>' % (unk_ans_count, len(questions)))
    return dataset

# %%
image_dir = "C:/Users/hieunc15/Documents/VisualQA/data/processed/images/%s/"
annotate_file = "C:/Users/hieunc15/Documents/VisualQA/data/raw/annotations/v2_mscoco_%s_annotations.json"
question_file = "C:/Users/hieunc15/Documents/VisualQA/data/raw/questions/v2_OpenEnded_mscoco_%s_questions.json"

vocab_answer_file = r"C:\Users\hieunc15\Documents\VisualQA\data\processed\vocab_answers.txt"
answer_dict = VocabDict(vocab_answer_file)
valid_answer_set = set(answer_dict.word_list)

train = vqa_processing(image_dir, annotate_file, question_file, valid_answer_set, 'train2014')
valid = vqa_processing(image_dir, annotate_file, question_file, valid_answer_set, 'val2014')


output_dir = r"C:\Users\hieunc15\Documents\VisualQA\data\processed\vqa_input"
np.save(output_dir + r'\train.npy', np.array(train))
np.save(output_dir + r'\valid.npy', np.array(valid))
np.save(output_dir + r'\train_valid.npy', np.array(train+valid))
# Out:
# building vqa train2014 dataset
# processing 10000 / 443757
# processing 20000 / 443757
# processing 30000 / 443757
# processing 40000 / 443757
# processing 50000 / 443757
# processing 60000 / 443757
# processing 70000 / 443757
# processing 80000 / 443757
# processing 90000 / 443757
# processing 100000 / 443757
# processing 110000 / 443757
# processing 120000 / 443757
# processing 130000 / 443757
# processing 140000 / 443757
# processing 150000 / 443757
# processing 160000 / 443757
# processing 170000 / 443757
# processing 180000 / 443757
# processing 190000 / 443757
# processing 200000 / 443757
# processing 210000 / 443757
# processing 220000 / 443757
# processing 230000 / 443757
# processing 240000 / 443757
# processing 250000 / 443757
# processing 260000 / 443757
# processing 270000 / 443757
# processing 280000 / 443757
# processing 290000 / 443757
# processing 300000 / 443757
# processing 310000 / 443757
# processing 320000 / 443757
# processing 330000 / 443757
# processing 340000 / 443757
# processing 350000 / 443757
# processing 360000 / 443757
# processing 370000 / 443757
# processing 380000 / 443757
# processing 390000 / 443757
# processing 400000 / 443757
# processing 410000 / 443757
# processing 420000 / 443757
# processing 430000 / 443757
# processing 440000 / 443757
# total 21164 out of 443757 answers are <unk>
# building vqa val2014 dataset
# processing 10000 / 214354
# processing 20000 / 214354
# processing 30000 / 214354
# processing 40000 / 214354
# processing 50000 / 214354
# processing 60000 / 214354
# processing 70000 / 214354
# processing 80000 / 214354
# processing 90000 / 214354
# processing 100000 / 214354
# processing 110000 / 214354
# processing 120000 / 214354
# processing 130000 / 214354
# processing 140000 / 214354
# processing 150000 / 214354
# processing 160000 / 214354
# processing 170000 / 214354
# processing 180000 / 214354
# processing 190000 / 214354
# processing 200000 / 214354
# processing 210000 / 214354
# total 10342 out of 214354 answers are <unk>
